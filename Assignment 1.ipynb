# %%
##Assignment 1 : Take two inputs and store in variable x and y,find x to the power y

# %%
x=int(input("Enter the value of x"))
y=int(input("Enter the value of y"))
print('Result:',pow(x,y))
# Out:
# Enter the value of x2
# Enter the value of y3
# Result: 8
